# %% [markdown]
# # very first steps in Jupyter Lab
#
# In Jupyter there are at least two different field: Markdown and Code

# %%
#this is a code cell which can be executed
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# One can do all the documentation within a Jupyter Notebook. It is also possible to use LaTex for formating $\frac{1}{2}=0.5$

# %% [markdown]
# ![image.png](attachment:e13370bd-811d-4e3e-a5a1-0b930e55dd31.png)
# Or paste some images

# %% [markdown]
# The images will be stores within the .ipynb file
